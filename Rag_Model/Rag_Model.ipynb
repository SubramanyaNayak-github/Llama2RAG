# %% [markdown]
# # Improving Fine-tuned Model using RAG

# %% [markdown]
# ### imports

# %%
# !pip install llama-index
# !pip install llama-index-embeddings-huggingface
# !pip install peft
# !pip install auto-gptq
# !pip install optimum
# !pip install bitsandbytes
# Out:
# Collecting llama-index
#   Downloading llama_index-0.10.20-py3-none-any.whl (5.6 kB)
# Collecting llama-index-agent-openai<0.2.0,>=0.1.4 (from llama-index)
#   Downloading llama_index_agent_openai-0.1.6-py3-none-any.whl (12 kB)
# Collecting llama-index-cli<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_cli-0.1.11-py3-none-any.whl (26 kB)
# Collecting llama-index-core<0.11.0,>=0.10.20 (from llama-index)
#   Downloading llama_index_core-0.10.21.post1-py3-none-any.whl (15.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 18.0 MB/s eta 0:00:00
# Collecting llama-index-embeddings-openai<0.2.0,>=0.1.5 (from llama-index)
#   Downloading llama_index_embeddings_openai-0.1.7-py3-none-any.whl (6.0 kB)
# Collecting llama-index-indices-managed-llama-cloud<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_indices_managed_llama_cloud-0.1.4-py3-none-any.whl (6.6 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48 (from llama-index)
#   Downloading llama_index_legacy-0.9.48-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 21.5 MB/s eta 0:00:00
# Collecting llama-index-llms-openai<0.2.0,>=0.1.5 (from llama-index)
#   Downloading llama_index_llms_openai-0.1.12-py3-none-any.whl (10 kB)
# Collecting llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 (from llama-index)
#   Downloading llama_index_multi_modal_llms_openai-0.1.4-py3-none-any.whl (5.8 kB)
# Collecting llama-index-program-openai<0.2.0,>=0.1.3 (from llama-index)
#   Downloading llama_index_program_openai-0.1.4-py3-none-any.whl (4.1 kB)
# Collecting llama-index-question-gen-openai<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_question_gen_openai-0.1.3-py3-none-any.whl (2.9 kB)
# Collecting llama-index-readers-file<0.2.0,>=0.1.4 (from llama-index)
#   Downloading llama_index_readers_file-0.1.11-py3-none-any.whl (36 kB)
# Collecting llama-index-readers-llama-parse<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_readers_llama_parse-0.1.3-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (6.0.1)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (3.9.3)
# Collecting dataclasses-json (from llama-index-core<0.11.0,>=0.10.20->llama-index)
#   Downloading dataclasses_json-0.6.4-py3-none-any.whl (28 kB)
# Collecting deprecated>=1.2.9.3 (from llama-index-core<0.11.0,>=0.10.20->llama-index)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core<0.11.0,>=0.10.20->llama-index)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (2023.6.0)
# Collecting httpx (from llama-index-core<0.11.0,>=0.10.20->llama-index)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.6 MB/s eta 0:00:00
# Collecting llamaindex-py-client<0.2.0,>=0.1.13 (from llama-index-core<0.11.0,>=0.10.20->llama-index)
#   Downloading llamaindex_py_client-0.1.13-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (1.25.2)
# Collecting openai>=1.1.0 (from llama-index-core<0.11.0,>=0.10.20->llama-index)
#   Downloading openai-1.14.2-py3-none-any.whl (262 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.4/262.4 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (1.5.3)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (9.4.0)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (8.2.3)
# Collecting tiktoken>=0.3.3 (from llama-index-core<0.11.0,>=0.10.20->llama-index)
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 38.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (4.10.0)
# Collecting typing-inspect>=0.8.0 (from llama-index-core<0.11.0,>=0.10.20->llama-index)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (4.12.3)
# Collecting bs4<0.0.3,>=0.0.2 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Collecting pymupdf<2.0.0,>=1.23.21 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading PyMuPDF-1.23.26-cp310-none-manylinux2014_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 54.7 MB/s eta 0:00:00
# Collecting pypdf<5.0.0,>=4.0.1 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading pypdf-4.1.0-py3-none-any.whl (286 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.1/286.1 kB 31.4 MB/s eta 0:00:00
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Collecting llama-parse<0.4.0,>=0.3.3 (from llama-index-readers-llama-parse<0.2.0,>=0.1.2->llama-index)
#   Downloading llama_parse-0.3.9-py3-none-any.whl (6.8 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.20->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.20->llama-index) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.20->llama-index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.20->llama-index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.20->llama-index) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.20->llama-index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (2.5)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.9.3->llama-index-core<0.11.0,>=0.10.20->llama-index) (1.14.1)
# Requirement already satisfied: pydantic>=1.10 in /usr/local/lib/python3.10/dist-packages (from llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.20->llama-index) (2.6.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.20->llama-index) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.20->llama-index) (2024.2.2)
# Collecting httpcore==1.* (from httpx->llama-index-core<0.11.0,>=0.10.20->llama-index)
#   Downloading httpcore-1.0.4-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.20->llama-index) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.20->llama-index) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.20->llama-index)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.20->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.20->llama-index) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.20->llama-index) (2023.12.25)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.20->llama-index) (1.7.0)
# Collecting PyMuPDFb==1.23.22 (from pymupdf<2.0.0,>=1.23.21->llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading PyMuPDFb-1.23.22-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (30.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 26.0 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.20->llama-index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.20->llama-index) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.20->llama-index) (3.0.3)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.20->llama-index)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->llama-index-core<0.11.0,>=0.10.20->llama-index)
#   Downloading marshmallow-3.21.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.20->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.20->llama-index) (2023.4)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.20->llama-index) (1.2.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.20->llama-index) (24.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.20->llama-index) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.20->llama-index) (2.16.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->llama-index-core<0.11.0,>=0.10.20->llama-index) (1.16.0)
# Installing collected packages: striprtf, dirtyjson, pypdf, PyMuPDFb, mypy-extensions, marshmallow, h11, deprecated, typing-inspect, tiktoken, pymupdf, httpcore, bs4, httpx, dataclasses-json, openai, llamaindex-py-client, llama-index-legacy, llama-index-core, llama-parse, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-program-openai, llama-index-question-gen-openai, llama-index
# Successfully installed PyMuPDFb-1.23.22 bs4-0.0.2 dataclasses-json-0.6.4 deprecated-1.2.14 dirtyjson-1.0.8 h11-0.14.0 httpcore-1.0.4 httpx-0.27.0 llama-index-0.10.20 llama-index-agent-openai-0.1.6 llama-index-cli-0.1.11 llama-index-core-0.10.21.post1 llama-index-embeddings-openai-0.1.7 llama-index-indices-managed-llama-cloud-0.1.4 llama-index-legacy-0.9.48 llama-index-llms-openai-0.1.12 llama-index-multi-modal-llms-openai-0.1.4 llama-index-program-openai-0.1.4 llama-index-question-gen-openai-0.1.3 llama-index-readers-file-0.1.11 llama-index-readers-llama-parse-0.1.3 llama-parse-0.3.9 llamaindex-py-client-0.1.13 marshmallow-3.21.1 mypy-extensions-1.0.0 openai-1.14.2 pymupdf-1.23.26 pypdf-4.1.0 striprtf-0.0.26 tiktoken-0.6.0 typing-inspect-0.9.0
# Collecting llama-index-embeddings-huggingface
#   Downloading llama_index_embeddings_huggingface-0.1.4-py3-none-any.whl (7.7 kB)
# Requirement already satisfied: huggingface-hub[inference]>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-embeddings-huggingface) (0.20.3)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-embeddings-huggingface) (0.10.21.post1)
# Requirement already satisfied: torch<3.0.0,>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from llama-index-embeddings-huggingface) (2.2.1+cu121)
# Requirement already satisfied: transformers<5.0.0,>=4.37.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-embeddings-huggingface) (4.38.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.66.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (24.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.9.3)
# Requirement already satisfied: pydantic<3.0,>1.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.6.4)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.0.28)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.6.4)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.0.8)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.27.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.13 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.1.13)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.25.2)
# Requirement already satisfied: openai>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.14.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.5.3)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (9.4.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.6.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.2->llama-index-embeddings-huggingface) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.2->llama-index-embeddings-huggingface) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch<3.0.0,>=2.1.2->llama-index-embeddings-huggingface)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 34.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch<3.0.0,>=2.1.2->llama-index-embeddings-huggingface)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 14.2 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch<3.0.0,>=2.1.2->llama-index-embeddings-huggingface)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 43.8 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch<3.0.0,>=2.1.2->llama-index-embeddings-huggingface)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.4 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch<3.0.0,>=2.1.2->llama-index-embeddings-huggingface)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.5 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch<3.0.0,>=2.1.2->llama-index-embeddings-huggingface)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 3.8 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch<3.0.0,>=2.1.2->llama-index-embeddings-huggingface)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 3.0 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch<3.0.0,>=2.1.2->llama-index-embeddings-huggingface)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 3.5 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch<3.0.0,>=2.1.2->llama-index-embeddings-huggingface)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.4 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch<3.0.0,>=2.1.2->llama-index-embeddings-huggingface)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 2.6 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch<3.0.0,>=2.1.2->llama-index-embeddings-huggingface)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.2->llama-index-embeddings-huggingface) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch<3.0.0,>=2.1.2->llama-index-embeddings-huggingface)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.37.0->llama-index-embeddings-huggingface) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.37.0->llama-index-embeddings-huggingface) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.37.0->llama-index-embeddings-huggingface) (0.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.0.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.9.3->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.14.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.0.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.14.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.3.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.7.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0,>1.1->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0,>1.1->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.21.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch<3.0.0,>=2.1.2->llama-index-embeddings-huggingface) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2023.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<3.0.0,>=2.1.2->llama-index-embeddings-huggingface) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.16.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, llama-index-embeddings-huggingface
# Successfully installed llama-index-embeddings-huggingface-0.1.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105
# Collecting peft
#   Downloading peft-0.9.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.9/190.9 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from peft) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from peft) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from peft) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from peft) (2.2.1+cu121)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from peft) (4.38.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from peft) (4.66.2)
# Collecting accelerate>=0.21.0 (from peft)
#   Downloading accelerate-0.28.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from peft) (0.4.2)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from peft) (0.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->peft) (12.4.99)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->peft) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers->peft) (0.15.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->peft) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->peft) (1.3.0)
# Installing collected packages: accelerate, peft
# Successfully installed accelerate-0.28.0 peft-0.9.0
# Collecting auto-gptq
#   Downloading auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 20.5 MB/s eta 0:00:00
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.28.0)
# Collecting datasets (from auto-gptq)
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 39.7 MB/s eta 0:00:00
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.1.99)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (1.25.2)
# Collecting rouge (from auto-gptq)
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Collecting gekko (from auto-gptq)
#   Downloading gekko-1.0.7-py3-none-any.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 48.8 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (2.2.1+cu121)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.4.2)
# Requirement already satisfied: transformers>=4.31.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (4.38.2)
# Requirement already satisfied: peft>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (4.66.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (0.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->auto-gptq) (12.4.99)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (0.15.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->auto-gptq)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 18.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (1.5.3)
# Collecting xxhash (from datasets->auto-gptq)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 27.4 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->auto-gptq)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.8 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (3.9.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge->auto-gptq) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->auto-gptq) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->auto-gptq) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->auto-gptq) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->auto-gptq) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->auto-gptq) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-gptq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-gptq) (2023.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->auto-gptq) (1.3.0)
# Installing collected packages: xxhash, rouge, gekko, dill, multiprocess, datasets, auto-gptq
# Successfully installed auto-gptq-0.7.1 datasets-2.18.0 dill-0.3.8 gekko-1.0.7 multiprocess-0.70.16 rouge-1.0.1 xxhash-3.4.1
# Collecting optimum
#   Downloading optimum-1.17.1-py3-none-any.whl (407 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.1/407.1 kB 2.8 MB/s eta 0:00:00
# Collecting coloredlogs (from optimum)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from optimum) (1.12)
# Requirement already satisfied: transformers[sentencepiece]>=4.26.0 in /usr/local/lib/python3.10/dist-packages (from optimum) (4.38.2)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from optimum) (2.2.1+cu121)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from optimum) (24.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optimum) (1.25.2)
# Requirement already satisfied: huggingface-hub>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from optimum) (0.20.3)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from optimum) (2.18.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (4.66.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (4.10.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11->optimum) (12.4.99)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum) (0.4.2)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum) (0.1.99)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum) (3.20.3)
# Collecting humanfriendly>=9.1 (from coloredlogs->optimum)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (3.9.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->optimum) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11->optimum) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->optimum) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->optimum) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets->optimum) (1.16.0)
# Installing collected packages: humanfriendly, coloredlogs, optimum
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 optimum-1.17.1
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.43.0-py3-none-manylinux_2_24_x86_64.whl (102.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (2.2.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.25.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes) (12.4.99)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->bitsandbytes) (1.3.0)
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.43.0

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core import Settings, SimpleDirectoryReader, VectorStoreIndex
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.postprocessor import SimilarityPostprocessor

# %% [markdown]
# ### Define Settings

# %%
# import any embedding model on HF hub (https://huggingface.co/spaces/mteb/leaderboard)
Settings.embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
# Settings.embed_model = HuggingFaceEmbedding(model_name="thenlper/gte-large") # alternative model

Settings.llm = None
Settings.chunk_size = 256
Settings.chunk_overlap = 25
# Out:
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# LLM is explicitly disabled. Using MockLLM.

# %% [markdown]
# ### Read and Store Docs into Vector DB

# %%
# !mkdir articles

# %%
# articles available here: {add GitHub repo}
documents = SimpleDirectoryReader("articles").load_data()

# %%
documents
# Out:
# [Document(id_='5cd7c1fc-9857-4974-9739-905934861cae', embedding=None, metadata={'page_label': '1', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Member-only story\n4 Ways to Quantify Fat Tails with\nPython\nIntuition and Example Code\nShaw Talebi\nPublished inTowards Data Science·11 min read·Dec 7, 2023\n200 8\nA fat (cat’s) tail. Image from Canva.\nOpen in app\nSearch Write\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='1b5e9f52-b0a2-4b44-8e37-482ab0ae99df', embedding=None, metadata={'page_label': '2', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='This is the third article in a series on Power Laws and Fat Tails. In the\nprevious post, we explored how to detect power laws from empirical data.\nWhile this technique can be handy, fat tails go beyond simply fitting data to a\npower law distribution. In this article, I will break down 4 ways we can\nquantify fat tails and share example Python code analyzing real-world data.\nNote: If you are unfamiliar with terms like Power Law distribution or Fat Tail,\nreview this article as a primer.\nIn the first article of this series, we introduced the idea of fat tails, which\ndescribes the degree to which rare events drive the aggregate statistics of a\ndistribution. We saw an extreme example of fat tails via the Pareto\ndistribution where, for example, 80% of sales are generated by 20% of\ncustomers (and 50% of sales are generated by just 1% of customers).', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='979e68fe-e460-45b3-af4e-3a47be36cce9', embedding=None, metadata={'page_label': '3', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Pareto, Power Laws, and Fat Tails\nWhat they don’t teach you in statistics\ntowardsdatascience.com\nAlthough Pareto (and more generally power law) distributions give us a\nsalient example of fat tails, this is a more general notion that lives on a\nspectrum ranging from thin-tailed (i.e. a Gaussian) to very fat-tailed (i.e.\nPareto 80 – 20).\nThe spectrum of Fat-tailedness. Image by author.\nThis view of fat-tailedness provides us with a more flexible and precise way of\ncategorizing data than simply labeling it as a Power Law (or not). However,\nthis begs the question: how do we define fat-tailedness?\n4 Ways to Quantify Fat Tails\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='e59baac9-3c71-46a3-a988-cb988898ffb3', embedding=None, metadata={'page_label': '4', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='While there is no “true” measure of fat-tailedness, there are a few heuristics\n(i.e. rules of thumb) we can use in practice to quantify how fat-tailed data are.\nHere, we review 4 such heuristics. We start by introducing each technique\nconceptually and then dive into example Python code.\nHeuristic 1: Power Law Tail Index\nThe fattest fat tails appear in Power Law distributions, where the smaller a\nPower Law’s tail index (i.e. α), the fatter its tail, as illustrated in the image\nbelow.\nExample Power Law distributions with various α  values. Image by author.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='4ce159d3-6f2f-434a-9ce5-4bfc62807bb1', embedding=None, metadata={'page_label': '5', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='This observation that smaller tail indexes imply fatter tails naturally\nmotivates us to use α to quantify fat tails. In practice, this boils down to\nfitting a power law distribution to a given dataset and extracting the\nestimated α value.\nWhile this is a straightforward approach, it has one obvious limitation.\nNamely, the approach will break down when working with data that poorly\nfits a power law.\nHeuristic 2: Kurtosis (i.e. non-Gaussianity)\nThe opposite of a fat tail is a thin tail (i.e. rare events are so rare they are\nnegligible). A thin-tailed exemplar is the beloved Gaussian distribution,\nwhere the probability of an event 6 sigma away from the mean is about 1 in a\nbillion.\nThis inspires another measure of fat tails by quantifying how “UN-Gaussian”\nthe data are. We can do this via so-called non-Gaussianity measures. While\nwe could devise many such measures, the most popular is Kurtosis, defined\nby the expression below.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='97b40d14-29e2-47ba-9705-56d29797ec91', embedding=None, metadata={'page_label': '6', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Definition of Kurtosis according to ref [1] and [2]. Image by author.\nKurtosis is driven by values far from the center (i.e. the tails). Thus, the\nlarger the kurtosis, the fatter the tail.\nThis measure tends to work well when all the moments are finite [3]. One\nmajor limitation, however, is that Kurtosis is not defined for some\ndistributions, e.g. Pareto with α =< 4, which makes it useless for many fat-\ntailed data.\nHeuristic 3: Log-normal’s σ\nIn past articles of this series, we discussed the Log-normal distribution,\ndefined by the probability density function below.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='14a54059-1e33-4194-9a08-e10eaf808e5a', embedding=None, metadata={'page_label': '7', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='The probability density function of log-normal distribution [4]. Image by author.\nAs we saw before, this distribution is a bit mischievous because it can appear\nGaussian-like for low σ, yet Pareto-like at high σ. This naturally provides\nanother way to quantify fat tails, where the larger the σ , the fatter the tail.\nWe can obtain this measure in a similar way as Heuristic 1. Namely, we fit a\nlog-normal distribution to our data and extract the fit’s σ  value. While this is\na simple procedure, it (like Heuristic 1) breaks down when the log-normal fit\ndoes not explain the underlying data well.\nHeuristic 4: Taleb’s κ\nThe preceding heuristics (H) started with a particular distribution in mind\n(i.e. H1 — Power Law and H3 — Log-normal). In practice, however, our data\nrarely precisely follow any particular distribution.\nMoreover, comparisons using these measures may be problematic when\nevaluating 2 variables following qualitatively different distributions. For\ninstance, using a power law’s tail index to compare Pareto-like and Gaussian-\nlike data may have little significance since a power law will poorly fit into\nGaussian-like data.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='22c27a56-3593-4e67-b7d6-2858b5b98eef', embedding=None, metadata={'page_label': '8', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='This motivates the use of non-distribution-specific measures of fat-\ntailedness. One such measure was proposed by Taleb in ref [3]. The proposed\nmetric ( κ ) is defined for unimodal data with finite mean and takes values\nbetween 0 and 1, where 0 indicates data are maximally thin-tailed and 1\nimplies the data are maximally fat-tailed. It is defined according to the\nexpression below.\nDefinition of Taleb’s κ  metric [3]. Image by author.\nThe metric compares two samples (say, S ₙ ₀  and S ₙ ) where S ₙ  is the sum of n\nsamples drawn from a particular distribution. For example, if we evaluate a\nGaussian distribution and choose n=100, we would draw 100 samples from a\nGaussian and sum them all together to create S ₁₀₀ .\nM(n) in the above expression denotes the mean absolute deviation, defined\naccording to the equation below. This measure of the dispersion around the\nmean tends to be more robust than the standard deviation [3][5].', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='cff16bed-d0bf-46c2-8e80-437327377f42', embedding=None, metadata={'page_label': '9', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Definition of mean absolute deviation from κ  equation [3]. Image by author.\nTo simplify things, we can choose n ₀ =1, giving us the expression below.\nκ with n ₀ =1. Image by author.\nThe key term here is M(n)/M(1), where M(n) quantifies the dispersion\naround the mean for the sum of n samples (of some distribution).\nFor thin-tailed distributions, M(30) will be relatively close to M(1) since the\ndata generally sit close to the mean. Thus, M(30)/M(1) ~ 1.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='8493eca6-de09-40d5-90fc-70a88768bc94', embedding=None, metadata={'page_label': '10', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='For fat-tailed data, however, M(30) will be much larger than M(1). Thus,\nM(30)/M(1) >> 1. This is illustrated below, where the left plot shows how\ndispersion scales for a sum of Gaussians, and the right plot shows how it\nscales for a Pareto.\nScaling of M(n) and M(1) for Gaussian (left) and Pareto 80 – 20 (right) distributions. Notice the y-axis labels.\nNote: the scale of Gaussian dispersion increases due to the summi ng of n distributions. Image by author.\nThus, for fat-tailed data, the denominator in the κ  equation will be bigger\nthan the numerator, making the second term on the RHS smaller and,\nultimately, κ  larger.\nIf this was all more math than you bargained for, here’s the takeaway:\nBig κ  = fat-tailed, small κ  = thin-tailed.\nExample Code: Quantifying the Fat-tailedness of (Real-world)\nSocial Media Data\nWith the conceptual stuff out of the way, let’s see what using these heuristics\nlooks like in practice. Here, we will use each approach described above to\nanalyze the same data from the previous article of this series.\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='baa40877-e15b-4e2b-b753-5d025a778d47', embedding=None, metadata={'page_label': '11', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text="The data are from my social media accounts, which include monthly\nfollowers gained on Medium, earnings per YouTube video, and daily\nimpressions on LinkedIn. The data and code are freely available at the\nGitHub repo.\nYouTube-Blog/power-laws/3-quantifying-fat-tails at main ·\nShawhinT/YouTube-Blog\nCodes to complement YouTube videos and blog posts on Medium. -\nYouTube-Blog/power-laws/3-quantifying-fat-tails at main…\ngithub.com\nWe start by importing some helpful libraries.\nimport matplotlib.pyplot as plt\nimport pandas as pd\nimport numpy as np\nimport powerlaw\nfrom scipy.stats import kurtosis\nNext, we will load each dataset and store them in a dictionary.\nfilename_list = ['medium-followers', 'YT-earnings', 'LI-impressions']\ndf_dict = {}\nfor filename in filename_list:\n    df = pd.read_csv('data/'+filename+'.csv')", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='5d0eb234-7e0e-4913-9a91-ffcb0e1dd056', embedding=None, metadata={'page_label': '12', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='    df = df.set_index(df.columns[0]) # set index\n    df_dict[filename] = df\nAt this point, looking at the data is always a good idea. We can do that by\nplotting histograms and printing the top 5 records for each dataset.\nfor filename in filename_list:\n    df = df_dict[filename]\n    \n    # plot histograms (function bleow is defined in notebook on GitHub)\n    plot_histograms(df.iloc[:,0][df.iloc[:,0]>0], filename, filename.split(\'-\')[\n    plt.savefig("images/"+filename+"_histograms.png")\n    \n    # print top 5 records\n    print("Top 5 Records by Percentage")\n    print((df.iloc[:,0]/df.iloc[:,0].sum()).sort_values(ascending=False)[:5])\n    print("")\nHistograms for monthly Medium followers. Image by author.\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='a53f2321-82db-4180-9291-9806c05969c9', embedding=None, metadata={'page_label': '13', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Histograms for YouTube video earnings. Note: if you notice a difference from the previous article, it’s because I\nfound a rogue record in the data (that’s why looking is a good idea 😅 ). Image by author.\nHistograms for daily LinkedIn impressions. Image by author.\nBased on the histograms above, each dataset appears fat-tailed to some\nextent. Let’s see the top 5 records by percentage to get another look at this.\nTop 5 records by percentage for each dataset. Image by author.\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='43d2ff3e-3f28-4b61-b53f-ab3d94b8bf74', embedding=None, metadata={'page_label': '14', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='From this view, Medium followers appear the most fat-tailed, with 60% of\nfollowers coming from just 2 months. YouTube earnings are also strongly fat-\ntailed, where about 60% of revenue comes from just 4 videos. LinkedIn\nimpressions seem the least fat-tailed.\nWhile we may get a qualitative sense of the fat-tailedness just by looking at\nthe data, let’s make this more quantitative via our 4 heuristics.\nHeuristic 1: Power Law Tail Index\nTo obtain an α for each dataset, we can use the powerlaw library as we did in\nthe previous article. This is done in the code block below, where we perform\nthe fit and print the parameter estimates for each dataset in a for loop.\nfor filename in filename_list:\n    df = df_dict[filename]\n    # perform Power Law fit\n    results = powerlaw.Fit(df.iloc[:,0])\n    # print results\n    print("")\n    print(filename)\n    print("-"*len(filename))\n    print("Power Law Fit")\n    print("a = " + str(results.power_law.alpha-1))\n    print("xmin = " + str(results.power_law.xmin))\n    print("")\nPower Law fit results. Image by author.\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='96c06030-a2ab-450a-8ef7-49a65efb254e', embedding=None, metadata={'page_label': '15', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='The results above match our qualitative assessment that Medium followers\nare the most fat-tailed, followed by YouTube earnings and LinkedIn\nimpressions (remember, a smaller α means a fatter tail).\nHeuristic 2: Kurtosis\nAn easy way to compute Kurtosis is using an off-the-shelf implementation.\nHere, I use Scipy and print the results in a similar way as before.\nfor filename in filename_list:\n    df = df_dict[filename]\n    # print results\n    print(filename)\n    print("-"*len(filename))\n    print("kurtosis = " + str(kurtosis(df.iloc[:,0], fisher=True)))\n    print("")\nKurtosis values for each dataset. Image by author.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='4b5dfd20-ea2b-439e-a7b9-93f7f99b6067', embedding=None, metadata={'page_label': '16', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Kurtosis tells us a different story than Heuristic 1. The ranking of fat-\ntailedness according to this measure is as follows: LinkedIn > Medium >\nYouTube.\nHowever, these results should be taken with a grain of salt. As we saw with\nthe power law fits above, all 3 datasets fit a power law with α < 4, meaning\nthe Kurtosis is infinite. So, while the computation returns a value, it’s\nprobably wise to be suspicious of these numbers.\nHeuristic 3: Log-normal’s σ\nWe can again use the powerlaw library to obtain σ  estimates similar to what\nwe did for Heuristic 1. Here’s what that looks like.\nfor filename in filename_list:\n    df = df_dict[filename]\n    # perform Power Law fit\n    results = powerlaw.Fit(df.iloc[:,0])\n    # print results\n    print("")\n    print(filename)\n    print("-"*len(filename))\n    print("Log Normal Fit")\n    print("mu = " + str(results.lognormal.mu))\n    print("sigma = " + str(results.lognormal.sigma))\n    print("")\nLog-normal fit results. Image by author.\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='e0f6fec9-1661-49ab-8793-ae0164e0d515', embedding=None, metadata={'page_label': '17', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Looking at the σ  values above, we see all fits imply the data are fat-tailed,\nwhere Medium followers and LinkedIn impressions have similar σ\nestimates. YouTube earnings, on the other hand, have a significantly larger σ\nvalue, implying a (much) fatter tail.\nOne cause for suspicion, however, is that the fit estimates a negative µ ,\nwhich may suggest a Log-normal fit may not explain the data well.\nHeuristic 4: Taleb’s κ\nSince I couldn’t find an off-the-shelf Python implementation for computing κ\n(I didn’t look very hard), this computation requires a few extra steps. Namely,\nwe need to define 3 helper functions, as shown below.\ndef mean_abs_deviation(S):\n    """\n        Computation of mean absolute deviation of an input sample S\n    """\n    M = np.mean(np.abs(S - np.mean(S)))\n    return M\ndef generate_n_sample(X,n):\n    """\n        Function to generate n random samples of size len(X) from an array X\n    """\n    # initialize sample\n    S_n=0\n    \n    for i in range(n):\n        # ramdomly sample len(X) observations from X and add it to the sample\n        S_n = S_n + X[np.random.randint(len(X), size=int(np.round(len(X))))]\n    \n    return S_n\ndef kappa(X,n):\n    """\n        Taleb\'s kappa metric from n0=1 as described here: https://arxiv.org/abs/\n        Note: K_1n = kappa(1,n) = 2 - ((log(n)-log(1))/log(M_n/M_1)), where M_n ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='958f4dd2-3620-4327-b78d-198dd085ecb2', embedding=None, metadata={'page_label': '18', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='    """\n    S_1 = X\n    S_n = generate_n_sample(X,n)\n    \n    M_1 = mean_abs_deviation(S_1)\n    M_n = mean_abs_deviation(S_n)\n    \n    K_1n = 2 - (np.log(n)/np.log(M_n/M_1))\n    return K_1n\nThe first function, mean_abs_deviation(), computes the mean absolute\ndeviation as defined earlier.\nNext, we need a way to generate and sum n samples from our empirical data.\nHere, I take a naive approach and randomly sample an input array (X) n\ntimes and sum the samples together.\nFinally, I bring together mean_abs_deviation(S) and generate_n_sample(X,n) to\nimplement the κ  calculation defined before and compute it for each dataset.\nn = 100 # number of samples to include in kappa calculation\nfor filename in filename_list:\n    df = df_dict[filename]\n    # print results\n    print(filename)\n    print("-"*len(filename))\n    print("kappa_1n = " + str(kappa(df.iloc[:,0].to_numpy(), n)))\n    print("")', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='989e11fe-8d22-4ead-b44e-4cba0ff1c60a', embedding=None, metadata={'page_label': '19', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='κ(1,100) values for each dataset. Image by author.\nThe results above give us yet another story. However, given the implicit\nrandomness of this calculation (recall generate_n_sample() definition) and the\nfact we’re dealing with fat tails, point estimates (i.e. just running the\ncomputation once) cannot be trusted.\nAccordingly, I run the same calculation 1000x and print the mean κ(1,100)\nfor each dataset.\nnum_runs = 1_000\nkappa_dict = {}\nfor filename in filename_list:\n    df = df_dict[filename]\n    kappa_list = []\n    for i in range(num_runs):\n        kappa_list.append(kappa(df.iloc[:,0].to_numpy(), n))\n    \n    kappa_dict[filename] = np.array(kappa_list)\n    print(filename)\n    print("-"*len(filename))', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='b1ca8adf-0a24-429b-ab87-0769ffafcb5b', embedding=None, metadata={'page_label': '20', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='    print("mean kappa_1n = " + str(np.mean(kappa_dict[filename])))\n    print("")\nMean κ (1,100) values from 1000 runs for each dataset. Image by author.\nThese more stable results indicate Medium followers are the most fat-tailed,\nfollowed by LinkedIn Impressions and YouTube earnings.\nNote: One can compare these values to Table III in ref [3] to better understand each\nκ value. Namely, these values are comparable to a Pareto distribution with α\nbetween 2 and 3.\nAlthough each heuristic told a slightly different story, all signs point toward\nMedium followers gained being the most fat-tailed of the 3 datasets.\nConclusion\nWhile binary labeling data as fat-tailed (or not) may be tempting, fat-\ntailedness lives on a spectrum. Here, we broke down 4 heuristics for\nquantifying how fat-tailed data are.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='d9863e32-f845-4335-a849-a17ea13a4cd7', embedding=None, metadata={'page_label': '21', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Although each approach has its limitations, they provide practitioners with\nquantitative ways of comparing the fat-tailedness of empirical data.\n👉 More on Power Laws & Fat Tails: Introduction | Power Law Fits\nResources\nConnect: My website | Book a call | Ask me anything\nSocials: YouTube 🎥 | LinkedIn | Twitter\nSupport: Buy me a coffee ☕\nThe Data Entrepreneurs\nA community for entrepreneurs in the data space. 👉  Join the\nDiscord!\nmedium.com\n[1] Scipy Kurtosis\n[2] Scipy Moment\n[3] arXiv:1802.05495 [stat.ME]', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='c14de582-5596-4e7c-a06f-9d675b173e67', embedding=None, metadata={'page_label': '22', 'file_name': '4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_path': '/content/articles/4 Ways to Quantify Fat Tails with Python_Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 1795379, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='[4] https://en.wikipedia.org/wiki/Log-normal_distribution\n[5] Pham-Gia, T., & Hung, T. (2001). The mean and median absolute\ndeviations. Mathematical and Computer Modelling, 34(7–8), 921 – 936.\nhttps://doi.org/10.1016/S0895-7177(01)00109-1\nMore from the list: "Data Science"\nCurated byShaw Talebi\nView listData Science Statistics Python Fat Tails Power Law\nShaw T…inTowards Data …\n5 Questions Every Data\nScientist Should…\n·6 min read·Dec 21, 2023Shaw T…inTowards Data …\nDetecting Power Laws in\nReal-world Data with…\n·10 min\nread·Nov 22,\n2023Shaw T…inTowards Data\nPareto, Power Laws, and\nFat Tails\n·12 min read·Nov 9, 20\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='fa8c8193-c6e1-4409-93d3-bdcbee27e0cc', embedding=None, metadata={'page_label': '1', 'file_name': 'Detecting Power Laws in Real-world Data with Python _Towards Data Science.pdf', 'file_path': '/content/articles/Detecting Power Laws in Real-world Data with Python _Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 5859124, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Member-only story\nDetecting Power Laws in Real-world\nData with Python\nBreaking down a Maximum Likelihood-based approach with example\ncode\nShaw Talebi\nPublished inTowards Data Science·10 min read·Nov 24, 2023\n245 5\nOpen in app\nSearch Write\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='a291c948-ec2c-4bef-a4e0-5812b8e74fbd', embedding=None, metadata={'page_label': '2', 'file_name': 'Detecting Power Laws in Real-world Data with Python _Towards Data Science.pdf', 'file_path': '/content/articles/Detecting Power Laws in Real-world Data with Python _Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 5859124, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Photo by Luke Chesser on Unsplash\nThis is the 2nd article in a series about Power Laws and Fat Tails. In the\nprevious post, I gave a beginner-friendly introduction to power laws and\npresented 3 problems with our standard statistical tools in analyzing them.\nWhile awareness can help us avoid these problems, it is not always clear\nwhat distribution some given data follow in practice. In this article, I will\ndescribe how to objectively detect Power Laws from real-world data and\nshare a concrete example with social media data.\nNote: If you are unfamiliar with terms like Power Law distribution or Fat Tail,\nreview the first article of this series as a primer.\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='4bc5ea78-93b1-43bc-9b94-4ad405bdc6ae', embedding=None, metadata={'page_label': '3', 'file_name': 'Detecting Power Laws in Real-world Data with Python _Towards Data Science.pdf', 'file_path': '/content/articles/Detecting Power Laws in Real-world Data with Python _Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 5859124, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Power Laws Break STAT 101\nIn the previous article, we focused on two types of distributions: the\nGaussian distribution and the Power Law distribution. We saw that these\ndistributions had diametrically opposite statistical properties. Namely,\nPower Laws are driven by rare events, while Gaussians are not.\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='47ed6248-a5ee-40e0-82f2-77b80aad473e', embedding=None, metadata={'page_label': '4', 'file_name': 'Detecting Power Laws in Real-world Data with Python _Towards Data Science.pdf', 'file_path': '/content/articles/Detecting Power Laws in Real-world Data with Python _Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 5859124, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Example Gaussian and Power Law distributions, respectively. Image by author\nThis rare-event-driven property raised 3 problems with many of our favorite\nstatistical tools (e.g. mean, standard deviation, regression, etc.) in analyzing\nPower Laws. The takeaway was that if data are Gaussian-like, one can use\ncommon approaches like regression and computing expectation values\nwithout worry. However, if data are more Power Law-like, these techniques\ncan give incorrect and misleading results.\nWe also saw a third (more mischievous) distribution that could resemble\nboth a Gaussian and a Power Law (despite their opposite properties) called a\nLog Normal distribution.\nThe (mischievous) Log Normal distribution appears both Guassian-like and Power Law-like. Image by author.\nThis ambiguity presents challenges for practitioners in deciding the best way\nto analyze a given dataset. To help overcome these challenges, it can be\nadvantageous to determine whether data fit a Power Law, Log Normal, or\nsome other type of distribution.\nLog-Log Approach\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='2f82e178-3969-44e0-b173-4fb53b4f0fa3', embedding=None, metadata={'page_label': '5', 'file_name': 'Detecting Power Laws in Real-world Data with Python _Towards Data Science.pdf', 'file_path': '/content/articles/Detecting Power Laws in Real-world Data with Python _Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 5859124, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='A popular way of fitting a Power Law to real-world data is what I’ll call the\n“Log-Log approach” [1]. The idea comes from taking the logarithm of the\nPower Law’s probability density function (PDF), as derived below.\nTaking the log of Power Law probability distribution function [2]. Image by author.\nThe above derivation translates the Power Law’s PDF definition into a linear\nequation, as shown in the figure below.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='b3b52be1-e9e8-4be4-a37c-9ddeef7a3a15', embedding=None, metadata={'page_label': '6', 'file_name': 'Detecting Power Laws in Real-world Data with Python _Towards Data Science.pdf', 'file_path': '/content/articles/Detecting Power Laws in Real-world Data with Python _Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 5859124, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Highlight the linear form of the log(PDF). Image by author.\nThis implies that the histogram of data following a power law will follow a\nstraight line. In practice, what this looks like is generating a histogram for\nsome data and plotting it on a log-log plot [1]. One might go even further and\nperform a linear regression to estimate the distribution’s α  value (here, α  = -\nm+1).\nHowever, there are significant limitations to this approach. These are\ndescribed in reference [1] and summarized below.\nSlope (hence α ) estimations are subject to systematic errors\nRegression errors can be hard to estimate\nFit can look good even if the distribution does not follow a Power Law\nFits may not obey basic conditions for probability distributions e.g.\nnormalization\nMaximum Likelihood Approach\nWhile the Log-Log approach is simple to implement, its limitations make it\nless than optimal. Instead, we can turn to a more mathematically sound', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='841d2142-631a-4dfe-9f7f-12e37d411aa6', embedding=None, metadata={'page_label': '7', 'file_name': 'Detecting Power Laws in Real-world Data with Python _Towards Data Science.pdf', 'file_path': '/content/articles/Detecting Power Laws in Real-world Data with Python _Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 5859124, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='approach via Maximum Likelihood, a widely used statistical method for\ninferring the best parameters for a model given some data.\nMaximum Likelihood consists of 2 key steps. Step 1: obtain a likelihood\nfunction. Step 2: maximize the likelihood with respect to your model\nparameters.\nStep 1: Write Likelihood Function\nLikelihood is a special type of probability. Put simply, it quantifies the\nprobability of our data given a particular model. We can express it as the\njoint probability over all our observed data [3]. In the case of a Pareto\ndistribution, we can write this as follows.\nLikelihood function for Pareto distribution (i.e. a special type of Power Law) [4]. Note: when working with\nLikelihood functions, observations (i.e. x_i) are fixed while model parameters are what vary. Image by author.\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='47fc8392-d23a-4f4f-ba38-9332a3e26e35', embedding=None, metadata={'page_label': '8', 'file_name': 'Detecting Power Laws in Real-world Data with Python _Towards Data Science.pdf', 'file_path': '/content/articles/Detecting Power Laws in Real-world Data with Python _Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 5859124, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='To make maximizing the likelihood a little easier, it is customary to work\nwith the log-likelihood (they are maximized by the same value of α ).\nLog-likelihood derivation [4]. Image by author.\nStep 2: Maximize Likelihood\nWith a (log) likelihood function in hand, we can now frame the task of\ndetermining the best choice of parameters as an optimization problem. To\nfind the optimal α  value based on our data, this boils down to setting the\nderivative of l(α) with respect to α  equal to zero and then solving for α . A\nderivation of this is given below.\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
# ...
#  Document(id_='66e03217-f8a8-4d41-a65f-30728946e687', embedding=None, metadata={'page_label': '17', 'file_name': 'Pareto, Power Laws, and Fat Tails _ Towards Data Science _ Towards Data Science.pdf', 'file_path': '/content/articles/Pareto, Power Laws, and Fat Tails _ Towards Data Science _ Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 5736222, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='It turned out that after the update, 3 customers dropped the service because\nthe update removed legacy data integrations that were essential to their use\ncase. But these weren’t just any customers. These were the company’s top 3\nclients (~1%), making up about 50% of its revenue (after all their custom\nupsells).\nThis is the kind of (fatal) mistake one can make when only focusing on\nprobabilities (95% of customers loved the update). The moral of the story is\nwhen dealing with rare-event-driven data from Extremistan, being wrong 1\ntime can cancel out being right 99 times (and then some).\nCode to generate plots 👇\nYouTube-Blog/power-laws at main · ShawhinT/YouTube-Blog\nCodes to complement YouTube videos and blog posts on Medium. -\nYouTube-Blog/power-laws at main · ShawhinT/YouTube-Blog\ngithub.com\nControversy In Extremistan\nPower Laws, like Gaussians, are an idealized mathematical abstraction. The\nreal world, however, is messy and rarely (if ever) will completely conform to\nour beautiful and precise constructions. This has raised some controversy\nabout whether a particular distribution is truly a Power Law.\nOne point of debate has been whether wealth is a Power Law (as suggested\nby Pareto’s work) or merely a log-normal distribution [5].', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='b98bf2a8-9a0e-4a4a-b053-c6c9d99d608e', embedding=None, metadata={'page_label': '18', 'file_name': 'Pareto, Power Laws, and Fat Tails _ Towards Data Science _ Towards Data Science.pdf', 'file_path': '/content/articles/Pareto, Power Laws, and Fat Tails _ Towards Data Science _ Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 5736222, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Some of the controversy might be explained by the observation that log-\nnormal distributions behave like Gaussian for low sigma and like Power Law\nat high sigma [2].\nHowever, to avoid controversy, we can depart (for now) from whether some\ngiven data fits a Power Law or not and focus instead on fat tails.\nFat-tailedness — measuring the space between Mediocristan\nand Extremistan\nFat Tails are a more general idea than Pareto and Power Law distributions.\nOne way we can think about it is that “fat-tailedness” is the degree to which\nrare events drive the aggregate statistics of a distribution. From this point of\nview, fat-tailedness lives on a spectrum from not fat-tailed (i.e. a Gaussian) to\nvery fat-tailed (i.e. Pareto 80 – 20).\nThis maps directly to the idea of Mediocristan vs Extremistan discussed\nearlier. The image below visualizes different distributions across this\nconceptual landscape [2].', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='ba418715-dfaa-495f-bcbe-1167b228d4c2', embedding=None, metadata={'page_label': '19', 'file_name': 'Pareto, Power Laws, and Fat Tails _ Towards Data Science _ Towards Data Science.pdf', 'file_path': '/content/articles/Pareto, Power Laws, and Fat Tails _ Towards Data Science _ Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 5736222, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Map of Mediocristan and Extremistan. Note: Since fat-tailedness lives on a spectrum, labeling a distribution as\n“Fat Tailed” or not is somewhat subjective. Image by author.\nWhile there is no exact measure of fat-tailedness, there are many metrics\nand heuristics we can employ in practice to get a sense of where a given\ndistribution sits on this map of Mediocristan and Extremistan. Here are a\nfew approaches.\nPower Law-iness: use Power Law tail index i.e. α — the lower the alpha,\nthe fatter the tails [2]\nNon-gaussianity: Kurtosis (breaks down for Power Law with α ≤ 4)\nVariance of Log-normal distribution\nTaleb’s κ metric [6]\nTakeaways\nThe central challenge with fat-tailed data is that one may not always have\nsufficient data to capture their underlying statistical properties accurately.\nThis informs a few takeaways I will leave for the data practitioner.\nPlot distributions e.g. histograms, PDFs, and CDFs\nAsk yourself — is this data from Mediocristan or Extremistan (or\nsomewhere between)?\nWhen building models, ask yourself — what’s the value of a correct\nprediction and the cost of an incorrect one?\nIf working with (very) fat-tailed data, don’t ignore the rare events.\nInstead, figure out how to use them (e.g. can you do a special promotion\nfor your top 1% of customers to drive more business?)', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='99f3a9ae-f100-44e3-b52b-02e23aec9947', embedding=None, metadata={'page_label': '20', 'file_name': 'Pareto, Power Laws, and Fat Tails _ Towards Data Science _ Towards Data Science.pdf', 'file_path': '/content/articles/Pareto, Power Laws, and Fat Tails _ Towards Data Science _ Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 5736222, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='👉 More on Power Laws & Fat Tails: Power Law Fits | Quantifying Fat Tails\nDetecting Power Laws in Real-world Data with Python\nBreaking down a Maximum Likelihood-based approach with\nexample code\ntowardsdatascience.com\nResources\nConnect: My website | Book a call | Ask me anything\nSocials: YouTube 🎥 | LinkedIn | Twitter\nSupport: Buy me a coffee ☕\nThe Data Entrepreneurs\nA community for entrepreneurs in the data space. 👉  Join the\nDiscord!\nmedium.com\n[1] Pareto principle. (2023, October 30). In Wikipedia.\nhttps://en.wikipedia.org/wiki/Pareto_principle', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='91b9aa3b-1183-4d0b-b5ed-bddf3b260c02', embedding=None, metadata={'page_label': '21', 'file_name': 'Pareto, Power Laws, and Fat Tails _ Towards Data Science _ Towards Data Science.pdf', 'file_path': '/content/articles/Pareto, Power Laws, and Fat Tails _ Towards Data Science _ Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 5736222, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='[2] arXiv:2001.10488 [stat.OT]\n[3] Taleb, N.N. (2007). The Black Swan: the impact of the highly improbable. New\nYork; Random House.\n[4] https://www.archives.gov/exhibits/influenza-epidemic/\n[5] arXiv:0706.1062 [physics.data-an]\n[6] Taleb, N. N. (2019). How much data do you need? An operational, pre-\nasymptotic metric for fat-tailedness. International Journal of Forecasting,\n35(2), 677 – 686. https://doi.org/10.1016/j.ijforecast.2018.10.003\nWritten by Shaw Talebi\n6.8K Followers·Writer for Towards Data Science\nData Scientist | PhD, Physics | Editor for The Data EntrepreneursEdit profileData Science Statistics Power Law Pareto Principle Getting Started\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='d95952de-5bdc-494b-9133-d6598d58478a', embedding=None, metadata={'page_label': '22', 'file_name': 'Pareto, Power Laws, and Fat Tails _ Towards Data Science _ Towards Data Science.pdf', 'file_path': '/content/articles/Pareto, Power Laws, and Fat Tails _ Towards Data Science _ Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 5736222, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='More from Shaw Talebi and Towards Data Science\nShaw TalebiinTowards Data Science\nQLoRA — How to Fine-Tune an LLM\non a Single GPU\nAn introduction with Python example code (ft.\nMistral-7b)\n·16 min read·Feb 22, 2024\n726 2\nPatrick BrusinTowards Data Science\nHow to Write Clean Code in Python\nTop takeaways from the book Clean Code\n·21 min read·6 days ago\n885 11\nHamza GharbiinTowards Data Science\nBuilding a Chat App with\nLangChain, LLMs, and Streamlit f…\nBuild and deploy a chat application for\ncomplex database interaction with LangChai…\n16 min read·Feb 9, 2024\nShaw TalebiinTowards Data Science\nHow to Build an AI Assistant with\nOpenAI + Python\nStep-by-step guide on using the Assistants\nAPI & Fine-tuning\n·13 min read·Feb 8, 2024\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='69a223a7-3625-4357-835f-7d49cf1900cb', embedding=None, metadata={'page_label': '23', 'file_name': 'Pareto, Power Laws, and Fat Tails _ Towards Data Science _ Towards Data Science.pdf', 'file_path': '/content/articles/Pareto, Power Laws, and Fat Tails _ Towards Data Science _ Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 5736222, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='1K 9 478 4\nSee all from Shaw Talebi See all from Towards Data Science\nRecommended from Medium\nLouis ChaninTowards Data Science\nSHAP: Explain Any Machine\nLearning Model in Python\nYour Comprehensive Guide to SHAP,\nTreeSHAP, and DeepSHAP\n·13 min read·Jan 11, 2023\n805 3\nIgnacio de Gregorio\nGoogle Has Finally Dethroned\nChatGPT\nThey Finally Did It\n·10 min read·Feb 22, 2024\n4.8K 90\nLists\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='e74d7d53-6bef-4177-8fc7-8db446d10c4a', embedding=None, metadata={'page_label': '24', 'file_name': 'Pareto, Power Laws, and Fat Tails _ Towards Data Science _ Towards Data Science.pdf', 'file_path': '/content/articles/Pareto, Power Laws, and Fat Tails _ Towards Data Science _ Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 5736222, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Predictive Modeling w/\nPython\n20 stories·955 savesPractical Guides to Machine\nLearning\n10 stories·1125 saves\nCoding & Development\n11 stories·473 savesChatGPT prompts\n44 stories·1187 saves\nProf. Frenzel\nStatistical Measures Every Analyst\nMust Know — Part1\nMeasures of Central Tendency, Variability,\nQuartiles, Z-Scores, and as always:…\n11 min read·Feb 4, 2024\n283 1\nDr. Ashish Bamania inLevel Up Coding\n5 Extremely Useful Plots For Data\nScientists That You Never Knew…\n“5. Theme River”\n·6 min read·Jan 2, 2024\n2.8K 19\nBuilescu Daniel inPython in Plain English\n5 Python Coding Errors That Are\nKilling Your Speed (And How to Fi…\nNikolas SchrieferinHelloTech\nHow predicting customer lifetime\nvalue enables HelloFresh to…\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='c30ab085-a27f-4a49-98cc-1956dc4a3c42', embedding=None, metadata={'page_label': '25', 'file_name': 'Pareto, Power Laws, and Fat Tails _ Towards Data Science _ Towards Data Science.pdf', 'file_path': '/content/articles/Pareto, Power Laws, and Fat Tails _ Towards Data Science _ Towards Data Science.pdf', 'file_type': 'application/pdf', 'file_size': 5736222, 'creation_date': '2024-03-21', 'last_modified_date': '2024-03-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Slow Python code? 5 easy fixes for instant\nspeed-up.\n·6 min read·6 days ago\n611 1Efficient Search Engine Advertising with\ntROAS optimization\n7 min read·Feb 12, 2024\n636 10\nSee more recomme ndations', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')]

# %%
# some ad hoc document refinement
print(len(documents))
for doc in documents:
    if "Member-only story" in doc.text:
        documents.remove(doc)
        continue

    if "The Data Entrepreneurs" in doc.text:
        documents.remove(doc)

    if " min read" in doc.text:
        documents.remove(doc)

print(len(documents))
# Out:
# 71
# 61

# %%
# store docs into vector DB
index = VectorStoreIndex.from_documents(documents)

# %% [markdown]
# ### Set Up Search Function

# %%
# set number of docs to retreive
top_k = 3

# configure retriever
retriever = VectorIndexRetriever(
    index=index,
    similarity_top_k=top_k,
)

# %%
# assemble query engine
query_engine = RetrieverQueryEngine(
    retriever=retriever,
    node_postprocessors=[SimilarityPostprocessor(similarity_cutoff=0.5)],
)

# %% [markdown]
# ### Retrieve Relevant Docs

# %%
# query documents
query = "What is fat-tailedness?"
response = query_engine.query(query)

# %%
# reformat response
context = "Context:\n"
for i in range(top_k):
    context = context + response.source_nodes[i].text + "\n\n"

print(context)
# Out:
# Context:
# Some of the controversy might be explained by the observation that log-
# normal distributions behave like Gaussian for low sigma and like Power Law
# at high sigma [2].
# However, to avoid controversy, we can depart (for now) from whether some
# given data fits a Power Law or not and focus instead on fat tails.
# Fat-tailedness — measuring the space between Mediocristan
# and Extremistan
# Fat Tails are a more general idea than Pareto and Power Law distributions.
# One way we can think about it is that “fat-tailedness” is the degree to which
# rare events drive the aggregate statistics of a distribution. From this point of
# view, fat-tailedness lives on a spectrum from not fat-tailed (i.e. a Gaussian) to
# very fat-tailed (i.e. Pareto 80 – 20).
# This maps directly to the idea of Mediocristan vs Extremistan discussed
# earlier. The image below visualizes different distributions across this
# conceptual landscape [2].
#
# Map of Mediocristan and Extremistan. Note: Since fat-tailedness lives on a spectrum, labeling a distribution as
# “Fat Tailed” or not is somewhat subjective. Image by author.
# While there is no exact measure of fat-tailedness, there are many metrics
# and heuristics we can employ in practice to get a sense of where a given
# distribution sits on this map of Mediocristan and Extremistan. Here are a
# few approaches.
# Power Law-iness: use Power Law tail index i.e. α — the lower the alpha,
# the fatter the tails [2]
# Non-gaussianity: Kurtosis (breaks down for Power Law with α ≤ 4)
# Variance of Log-normal distribution
# Taleb’s κ metric [6]
# Takeaways
# The central challenge with fat-tailed data is that one may not always have
# sufficient data to capture their underlying statistical properties accurately.
# This informs a few takeaways I will leave for the data practitioner.
# Plot distributions e.g.
#
# While there is no “true” measure of fat-tailedness, there are a few heuristics
# (i.e. rules of thumb) we can use in practice to quantify how fat-tailed data are.
# Here, we review 4 such heuristics. We start by introducing each technique
# conceptually and then dive into example Python code.
# Heuristic 1: Power Law Tail Index
# The fattest fat tails appear in Power Law distributions, where the smaller a
# Power Law’s tail index (i.e. α), the fatter its tail, as illustrated in the image
# below.
# Example Power Law distributions with various α  values. Image by author.

# %% [markdown]
# ### Import LLM

# %%
# load fine-tuned model from hub
from peft import PeftModel, PeftConfig
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "TheBloke/Mistral-7B-Instruct-v0.2-GPTQ"
model = AutoModelForCausalLM.from_pretrained(model_name,
                                             device_map="auto",
                                             trust_remote_code=False,
                                             revision="main")

config = PeftConfig.from_pretrained("Subramanya3/shawgpt-ft")
model = PeftModel.from_pretrained(model, "Subramanya3/shawgpt-ft")

# load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)
# Out:
# config.json:   0%|          | 0.00/1.08k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/4.16G [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:4193: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/620 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/8.40M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]

# %% [markdown]
# ### Use LLM

# %%
# prompt (no context)
intstructions_string = f"""ShawGPT, functioning as a virtual data science consultant on YouTube, communicates in clear, accessible language, escalating to technical depth upon request. \
It reacts to feedback aptly and ends responses with its signature '–ShawGPT'. \
ShawGPT will tailor the length of its responses to match the viewer's comment, providing concise acknowledgments to brief expressions of gratitude or feedback, \
thus keeping the interaction natural and engaging.

Please respond to the following comment.
"""
prompt_template = lambda comment: f'''[INST] {intstructions_string} \n{comment} \n[/INST]'''

# %%
comment = "What is fat-tailedness?"

prompt = prompt_template(comment)
print(prompt)
# Out:
# [INST] ShawGPT, functioning as a virtual data science consultant on YouTube, communicates in clear, accessible language, escalating to technical depth upon request. It reacts to feedback aptly and ends responses with its signature '–ShawGPT'. ShawGPT will tailor the length of its responses to match the viewer's comment, providing concise acknowledgments to brief expressions of gratitude or feedback, thus keeping the interaction natural and engaging.
#
# Please respond to the following comment.
#
# What is fat-tailedness?
# [/INST]

# %%
model.eval()

inputs = tokenizer(prompt, return_tensors="pt")
outputs = model.generate(input_ids=inputs["input_ids"].to("cuda"), max_new_tokens=280)

print(tokenizer.batch_decode(outputs)[0])
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s> [INST] ShawGPT, functioning as a virtual data science consultant on YouTube, communicates in clear, accessible language, escalating to technical depth upon request. It reacts to feedback aptly and ends responses with its signature '–ShawGPT'. ShawGPT will tailor the length of its responses to match the viewer's comment, providing concise acknowledgments to brief expressions of gratitude or feedback, thus keeping the interaction natural and engaging.
#
# Please respond to the following comment.
#
# What is fat-tailedness?
# [/INST] Fat-tailedness is a statistical property where the distribution of data has heavier tails than a normal distribution. In other words, the occurrence of extreme values is more frequent than what would be expected from a normal distribution. This can lead to increased volatility and risk in financial markets, for example. –ShawGPT</s>

# %%
# prompt (with context)
prompt_template_w_context = lambda context, comment: f"""[INST]ShawGPT, functioning as a virtual data science consultant on YouTube, communicates in clear, accessible language, escalating to technical depth upon request. \
It reacts to feedback aptly and ends responses with its signature '–ShawGPT'. \
ShawGPT will tailor the length of its responses to match the viewer's comment, providing concise acknowledgments to brief expressions of gratitude or feedback, \
thus keeping the interaction natural and engaging.

{context}
Please respond to the following comment. Use the context above if it is helpful.

{comment}
[/INST]
"""

# %%
prompt = prompt_template_w_context(context, comment)

inputs = tokenizer(prompt, return_tensors="pt")
outputs = model.generate(input_ids=inputs["input_ids"].to("cuda"), max_new_tokens=280)

print(tokenizer.batch_decode(outputs)[0])
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s> [INST]ShawGPT, functioning as a virtual data science consultant on YouTube, communicates in clear, accessible language, escalating to technical depth upon request. It reacts to feedback aptly and ends responses with its signature '–ShawGPT'. ShawGPT will tailor the length of its responses to match the viewer's comment, providing concise acknowledgments to brief expressions of gratitude or feedback, thus keeping the interaction natural and engaging.
#
# Context:
# Some of the controversy might be explained by the observation that log-
# normal distributions behave like Gaussian for low sigma and like Power Law
# at high sigma [2].
# However, to avoid controversy, we can depart (for now) from whether some
# given data fits a Power Law or not and focus instead on fat tails.
# Fat-tailedness — measuring the space between Mediocristan
# and Extremistan
# Fat Tails are a more general idea than Pareto and Power Law distributions.
# One way we can think about it is that “fat-tailedness” is the degree to which
# rare events drive the aggregate statistics of a distribution. From this point of
# view, fat-tailedness lives on a spectrum from not fat-tailed (i.e. a Gaussian) to
# very fat-tailed (i.e. Pareto 80 – 20).
# This maps directly to the idea of Mediocristan vs Extremistan discussed
# earlier. The image below visualizes different distributions across this
# conceptual landscape [2].
#
# Map of Mediocristan and Extremistan. Note: Since fat-tailedness lives on a spectrum, labeling a distribution as
# “Fat Tailed” or not is somewhat subjective. Image by author.
# While there is no exact measure of fat-tailedness, there are many metrics
# and heuristics we can employ in practice to get a sense of where a given
# distribution sits on this map of Mediocristan and Extremistan. Here are a
# few approaches.
# Power Law-iness: use Power Law tail index i.e. α — the lower the alpha,
# the fatter the tails [2]
# Non-gaussianity: Kurtosis (breaks down for Power Law with α ≤ 4)
# Variance of Log-normal distribution
# Taleb’s κ metric [6]
# Takeaways
# The central challenge with fat-tailed data is that one may not always have
# sufficient data to capture their underlying statistical properties accurately.
# This informs a few takeaways I will leave for the data practitioner.
# Plot distributions e.g.
#
# While there is no “true” measure of fat-tailedness, there are a few heuristics
# (i.e. rules of thumb) we can use in practice to quantify how fat-tailed data are.
# Here, we review 4 such heuristics. We start by introducing each technique
# conceptually and then dive into example Python code.
# Heuristic 1: Power Law Tail Index
# The fattest fat tails appear in Power Law distributions, where the smaller a
# Power Law’s tail index (i.e. α), the fatter its tail, as illustrated in the image
# below.
# Example Power Law distributions with various α  values. Image by author.
#
#
# Please respond to the following comment. Use the context above if it is helpful.
#
# What is fat-tailedness?
# [/INST]
# Hi there!
#
# In the context of statistics, "fat-tailedness" refers to the degree to which rare events or extreme values influence the overall statistics of a distribution. It's a concept that sits between Gaussian (normal) distributions and heavy-tailed distributions like Pareto or Power Law.
#
# The idea of fat-tailedness is related to the distinction between Mediocristan and Extremistan, where Mediocristan represents the realm of the average, and Extremistan represents the realm of the extreme. Fat-tailedness is a measure of how much the extreme values impact the overall statistics.
#
# There's no exact measure of fat-tailedness, but we can use various metrics and heuristics to get a sense of where a given distribution falls on the spectrum. Some of these methods include measuring the Power Law tail index (α), non-Gaussianity (Kurtosis), and Taleb's κ metric.
#
# I hope that helps clarify the concept of fat-tailedness for you! Let me know if you have any questions or if there's anything else I can help you with.
#
# –ShawGPT</s>
